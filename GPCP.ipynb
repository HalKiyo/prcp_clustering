# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from tslearn.clustering import TimeSeriesKMeans
from scipy import stats
from sklearn.mixture import GaussianMixture
import cartopy.crs as ccrs
import colormaps as clm
import matplotlib as mpl

# %% [markdown]
# # データの準備

# %%
gpcp_path = "/docker/mnt/d/research/D3/cnn3/transfer/predictand/continuous/gpcp_5x5_coarse_std_MJJASO_monsoon.npy"
gpcp = np.squeeze(np.load(gpcp_path))

# %%
gpcp_flat = gpcp.reshape(44, 252)
gpcp_t = gpcp_flat.T
print(gpcp_t.shape)
# Out:
# (252, 44)

# %% [markdown]
# # 可視化

# %%
def draw_map(label, cluster_num=3):
    plt.rcParams["font.size"] = 18
    projection = ccrs.PlateCarree(central_longitude=180)
    img_extent = (-120, -30, -15, 55)
    
    cm = plt.cm.get_cmap('tab20', cluster_num)

    fig = plt.figure()
    ax = plt.subplot(projection=projection)
    ax.coastlines()
    mat = ax.matshow(label,
                     origin='upper',
                     extent=img_extent,
                     transform=projection,
                     cmap=cm,
                    )
    cbar = fig.colorbar(mat, ax=ax)
    plt.show()

# %%
def plot_km(data, labels, km, cluster_num=3):
    fig, axes = plt.subplots(n, figsize=(8, 18))
    plt.subplots_adjust(hspace=0.5)
    for i in range(cluster_num):
        ax = axes[i]
        for xx in data[labels == i]:
            ax.plot(xx.ravel()[:], "k-", alpha=.03)
        ax.plot(km.cluster_centers_[i].ravel()[:], "r-")
    plt.show()

# %% [markdown]
# # calc done

# %%
# gpcp
n = 3 # クラスタ数
met = 'softdtw' # or dtw

km_dtw = TimeSeriesKMeans(n_clusters=n,
                          random_state=42,
                         )

gpcp_labels = km_dtw.fit_predict(gpcp_t)
gpcp_all = gpcp_labels[:]
gpcp_map = np.reshape(gpcp_all, (14, 18))

draw_map(gpcp_map, cluster_num=n)
plot_km(gpcp_t, gpcp_labels, km_dtw, cluster_num=n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 9
#       3 met = 'softdtw' # or dtw
#       5 km_dtw = TimeSeriesKMeans(n_clusters=n,
#       6                           random_state=42,
#       7                          )
# ----> 9 gpcp_labels = km_dtw.fit_predict(gpcp_t)
#      10 gpcp_all = gpcp_labels[:]
#      11 gpcp_map = np.reshape(gpcp_all, (14, 18))
#
# File /usr/local/lib/python3.8/dist-packages/tslearn/clustering/kmeans.py:854, in TimeSeriesKMeans.fit_predict(self, X, y)
#     834 """Fit k-means clustering using X and then predict the closest cluster
#     835 each time series in X belongs to.
#     836
#    (...)
#     851     Index of the cluster each sample belongs to.
#     852 """
#     853 X = check_array(X, allow_nd=True, force_all_finite="allow-nan")
# --> 854 return self.fit(X, y).labels_
#
# File /usr/local/lib/python3.8/dist-packages/tslearn/clustering/kmeans.py:821, in TimeSeriesKMeans.fit(self, X, y)
#     819     print("Init %d" % (n_successful + 1))
#     820 n_attempts += 1
# --> 821 self._fit_one_init(X_, x_squared_norms, rs)
#     822 if self.inertia_ < min_inertia:
#     823     best_correct_centroids = self.cluster_centers_.copy()
#
# File /usr/local/lib/python3.8/dist-packages/tslearn/clustering/kmeans.py:637, in TimeSeriesKMeans._fit_one_init(self, X, x_squared_norms, rs)
#     635 elif isinstance(self.init, str) and self.init == "k-means++":
#     636     if self.metric == "euclidean":
# --> 637         if SKLEARN_VERSION_GREATER_THAN_OR_EQUAL_TO_1_3_0:
#     638             sample_weight = _check_sample_weight(None, X, dtype=X.dtype)
#     639             self.cluster_centers_ = _kmeans_plusplus(
#     640                 X.reshape((n_ts, -1)),
#     641                 self.n_clusters,
#    (...)
#     644                 random_state=rs,
#     645             )[0].reshape((-1, sz, d))
#
# NameError: name 'SKLEARN_VERSION_GREATER_THAN_OR_EQUAL_TO_1_3_0' is not defined

# %%
# gpcp
n = 5 # クラスタ数

km_dtw = TimeSeriesKMeans(n_clusters=n,
                          random_state=42,
                          metric="dtw")

gpcp_labels = km_dtw.fit_predict(gpcp_t)
gpcp_all = gpcp_labels[:]
gpcp_map = np.reshape(gpcp_all, (14, 18))

draw_map(gpcp_map, cluster_num=n)
plot_km(gpcp_t, gpcp_labels, km_dtw, cluster_num=n)

# %%
# gpcp
n = 10 # クラスタ数

km_dtw = TimeSeriesKMeans(n_clusters=n,
                          random_state=42,
                          metric="dtw")

gpcp_labels = km_dtw.fit_predict(gpcp_t)
gpcp_all = gpcp_labels[:]
gpcp_map = np.reshape(gpcp_all, (14, 18))

draw_map(gpcp_map, cluster_num=n)
plot_km(gpcp_t, gpcp_labels, km_dtw, cluster_num=n)
